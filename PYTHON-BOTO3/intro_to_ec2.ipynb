# %%
## import boto3 
import boto3

# import pprint from pprint
from pprint import pprint

## create a session object 
session = boto3.session.Session()

## create a client object(service_name='ec2', region_name='us-east-1') 
client = session.client(service_name='ec2', region_name='us-east-1')


def ec2_discribe_withclient():
    response = client.describe_instances()['Reservations']

    # when you see a list we must itirate
    for each_instance in response:
        for i in each_instance['Instances']:
            print(i['InstanceId'], i['ImageId'], i['LaunchTime'].strftime('%Y-%m-%d'), i['State']['Name'])
        # print(each_instance.keys())
        # nested loop
#         for instance in each_instance['Instances']:
#             pprint(instance)
            
        # when happen when you see a dictionary[we use the .keys() to the amount of keys it con
        # has]

# %% [markdown]
# ## Now using resource object to discribe instance

# %%
# now creating resource object 
resource = session.resource(service_name='ec2', region_name='us-east-1')
# .all()
# .filter()
# .limit()

def ec2_discribe_withresource():
    response = resource.instances.all()
    for i in response:
        pprint(dir(i))
        print(i.instance_id, i.image_id, i.state['Name'], i.launch_time.strftime('%Y-%m-%d'))
        

def lambda_handler():
    #ec2_discribe_withclient() 
    ec2_discribe_withresource()


if __name__ == "__main__":
    lambda_handler()
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_id',
#  'ami_launch_index',
#  'architecture',
#  'attach_classic_link_vpc',
#  'attach_volume',
#  'block_device_mappings',
#  'boot_mode',
#  'capacity_reservation_id',
#  'capacity_reservation_specification',
#  'classic_address',
#  'client_token',
#  'console_output',
#  'cpu_options',
#  'create_image',
#  'create_tags',
#  'delete_tags',
#  'describe_attribute',
#  'detach_classic_link_vpc',
#  'detach_volume',
#  'ebs_optimized',
#  'elastic_gpu_associations',
#  'elastic_inference_accelerator_associations',
#  'ena_support',
#  'enclave_options',
# ...

# %% [markdown]
# ## Create a function using either client or resource object to stop an ec2 instance

# %%
from __future__ import print_function

print(dir(print_function))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'compiler_flag', 'getMandatoryRelease', 'getOptionalRelease', 'mandatory', 'optional']
